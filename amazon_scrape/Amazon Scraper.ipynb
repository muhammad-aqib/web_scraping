# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

import pandas as pd

# %% [markdown]
# ### Initials

# %%
#Amazon URL
url = 'https://www.amazon.com/s?k={}&ref=nb_sb_noss'
search_query='ultrawide monitor'
last_page=20
final_items_list=[]

# %% [markdown]
# ### Final URL function

# %%
def get_url(search_term):
    search_term = search_term.replace(' ','+')
    final_url = url.format(search_term)
    final_url = final_url + '&page={}'
    return final_url

# %% [markdown]
# ### Get Product URL

# %%
def get_product_url(item):
    product_url = item.find('a',{'class':'a-link-normal a-text-normal'})['href']
    return 'https://amazon.com' + product_url

# %% [markdown]
# ### Extract Items

# %%
def extract_item(page_number):
    driver.get(get_url(search_query).format(str(page_number)))
    soup = BeautifulSoup(driver.page_source,'lxml')
    all_items = soup.find_all('div','s-include-content-margin s-border-bottom s-latency-cf-section')
    
    for item in all_items:
        try:
            item_name = item.find('span',{'class':'a-size-medium a-color-base a-text-normal','dir':'auto'}).text.strip()
            item_price = item.find('span',{'class':'a-offscreen'}).text.strip()
            item_rating = item.find('span',{'class':'a-icon-alt'}).text.strip()
            item_reviews = item.find('span',{'class':'a-size-base','dir':'auto'}).text.strip()
            product_url = get_product_url(item)

        except :
            continue
        finally:
            final_items_list.append((item_name, item_price, item_rating, item_reviews, product_url))

# %% [markdown]
# ### Run Chrome Driver

# %%
driver = webdriver.Chrome()

for i in range(1,last_page):
    final_items_list.append(extract_item(i))

driver.close()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-321-cebc97694861> in <module>
#       2
#       3 for i in range(1,last_page):
# ----> 4     final_items_list.append(extract_item(i))
#       5
#       6 driver.close()
#
# <ipython-input-320-f47e0e90a456> in extract_item(page_number)
#      15             continue
#      16         finally:
# ---> 17             final_items_list.append((item_name, item_price, item_rating, item_reviews, product_url))
#
# UnboundLocalError: local variable 'item_rating' referenced before assignment

# %% [markdown]
# ### Export to CSV

# %%
item_cols = ['item_name','item_price','item_rating','item_review','product_url']
items_df = pd.DataFrame(final_items_list, columns=item_cols)
items_df.to_csv('amazon_items.csv', index=False)

# %%
items_df
# Out:
#                                             item_name item_price  \
# 0   Sceptre IPS 24-Inch Business Computer Monitor ...    $119.97
# 1   Datacolor SpyderX Pro – Monitor Calibration De...    $166.29
# 2   ViewSonic VP2785-4K 27 Inch 4K Monitor USB C 9...    $897.98
# 3   Dell U2717D IPS 27" UltraSharp InfinityEdge Sl...    $614.00
# 4   Samsung 27-Inch CR50 Frameless Curved Gaming M...    $196.59
# 5   LG Ultrawide CB99 34" LED LCD Monitor 21:9 TAA...    $196.59
# 6   Samsung Electronics HG50NJ690UFXZA HJ690U 50" ...    $196.59
# 7   BenQ EL2870U 28 inch 4K Monitor for Gaming 1ms...    $299.99
# 8   Samsung C34H890WJN - 34 Inch (3440 x 1440) WQH...    $836.10
# 9   MSI 24” FHD (1920 x 1080) Non-Glare with Super...    $836.10
# 10  Samsung 24" FHD Monitor with Bezel-LESS Design...    $129.99
# 11  Samsung Business SH850 Series 24 Inch QHD 2560...    $289.99
# 12  ViewSonic VA2246MH-LED 22 Inch Full HD 1080p L...     $99.99
# 13  Monoprice 27in Zero-G Curved Gaming Monitor - ...    $169.98
# 14  ViewSonic VA3456-MHDJ 34 Inch Frameless 1440p ...    $980.00
# 15  MSI 32" FHD 1500R Curvature Non-Glare Super Na...    $980.00
# 16  Acer G276HL Kbix 27" Full HD (1920 x 1080) VA ...    $154.99
# 17  HP EliteDisplay E243 | 24" Monitor | HD IPS Sc...    $154.99
# 18  ViewSonic XG2405 24 Inch 1080p 1ms 144Hz Frame...    $420.97
# 19  LG 32UD60-B 4K UHD Monitor with AMD FreeSync, ...    $491.17
# 20  Sceptre IPS 27-Inch Business Computer Monitor ...    $139.97
# 21  LG 34WK650-W 34" UltraWide 21:9 IPS Monitor wi...    $296.99
# 22                                               None       None
# 23  Sceptre IPS 27-Inch Business Computer Monitor ...    $139.97
# 24  viozon Monitor and Laptop Mount, 2-in-1 Adjust...     $87.99
# 25  LG Ultrawide CB99 34" LED LCD Monitor 21:9 TAA...     $87.99
# 26  Samsung Electronics HG50NJ690UFXZA HJ690U 50" ...     $87.99
# 27  BenQ EL2870U 28 inch 4K Monitor for Gaming 1ms...    $299.99
# 28  Samsung C34H890WJN - 34 Inch (3440 x 1440) WQH...    $836.10
# 29  MSI 24” FHD (1920 x 1080) Non-Glare with Super...    $836.10
# 30  ViewSonic VA2246MH-LED 22 Inch Full HD 1080p L...     $99.99
# 31  Monoprice 27in Zero-G Curved Gaming Monitor - ...    $169.98
# 32  ViewSonic VA3456-MHDJ 34 Inch Frameless 1440p ...    $980.00
# 33  Samsung 24" FHD Monitor with Bezel-LESS Design...    $129.99
# 34  Samsung Business SH850 Series 24 Inch QHD 2560...    $289.99
# 35  MSI 32" FHD 1500R Curvature Non-Glare Super Na...    $289.99
# 36  Acer G276HL Kbix 27" Full HD (1920 x 1080) VA ...    $154.99
# 37  HP EliteDisplay E243 | 24" Monitor | HD IPS Sc...    $154.99
# 38  LG 32UD60-B 4K UHD Monitor with AMD FreeSync, ...    $491.17
# 39  HP 24f 23.8" Ultra Slim Bezels IPS LED Display...    $491.17
# 40  Samsung SD850 32" WQHD (2560x1440) 16:9 Aspect...    $314.95
# 41  MSI Non-Glare with Narrow Bezel Ultra Wide 21:...  $1,004.44
# 42  MSI 27” FHD (1920 x 1080) Non-Glare with Super...    $264.00
# 43  Sceptre IPS 24-Inch Business Computer Monitor ...    $119.97
# 44  LG 27UK850-W 27" 4K UHD IPS Monitor with HDR10...    $449.99
# 45                                               None       None
#
#            item_rating item_review  \
# 0   4.6 out of 5 stars       1,119
# 1   4.5 out of 5 stars       4,611
# 2   4.3 out of 5 stars         429
# 3   4.4 out of 5 stars         236
# 4   4.7 out of 5 stars         488
# 5   4.7 out of 5 stars         488
# 6   4.7 out of 5 stars         488
# 7   4.6 out of 5 stars       2,717
# 8   4.1 out of 5 stars          13
# 9   4.1 out of 5 stars          13
# 10  4.6 out of 5 stars         670
# 11  4.4 out of 5 stars          86
# 12  4.6 out of 5 stars       4,171
# 13  4.4 out of 5 stars          26
# 14  4.4 out of 5 stars          26
# 15  4.4 out of 5 stars          26
# 16  4.6 out of 5 stars         883
# 17  4.6 out of 5 stars         883
# 18  4.7 out of 5 stars       1,449
# 19  4.5 out of 5 stars         362
# 20  4.7 out of 5 stars       1,144
# 21  4.6 out of 5 stars         744
# 22                None        None
# 23  4.7 out of 5 stars       1,144
# 24  4.5 out of 5 stars       1,812
# 25  4.5 out of 5 stars       1,812
# 26  4.5 out of 5 stars       1,812
# 27  4.6 out of 5 stars       2,717
# 28  4.1 out of 5 stars          13
# 29  4.1 out of 5 stars          13
# 30  4.6 out of 5 stars       4,171
